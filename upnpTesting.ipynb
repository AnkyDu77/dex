# %%
import upnpy

# %%
upnp = upnpy.UPnP()

# %%
devices = upnp.discover()
devices
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/http/client.py in _get_hostport(self, host, port)
#     876                 try:
# --> 877                     port = int(host[i+1:])
#     878                 except ValueError:
#
# ValueError: invalid literal for int() with base 10: '7678dial.xml'
#
# During handling of the above exception, another exception occurred:
#
# InvalidURL                                Traceback (most recent call last)
# <ipython-input-3-eafcbff43bbc> in <module>
# ----> 1 devices = upnp.discover()
#       2 devices
#
# ~/anaconda3/lib/python3.7/site-packages/upnpy/upnp/UPnP.py in discover(self, delay, **headers)
#      31
#      32         discovered_devices = []
# ---> 33         for device in self.ssdp.m_search(discover_delay=delay, st='upnp:rootdevice', **headers):
#      34             discovered_devices.append(device)
# ...

# %%
device = upnp.get_igd()
device
# Out:
# ---------------------------------------------------------------------------
# IGDError                                  Traceback (most recent call last)
# <ipython-input-4-4c07a11f25e2> in <module>
# ----> 1 device = upnp.get_igd()
#       2 device
#
# ~/anaconda3/lib/python3.7/site-packages/upnpy/upnp/UPnP.py in get_igd(self)
#      60             raise exceptions.IGDError('Multiple IGDs found. Specify one manually.')
#      61         else:
# ---> 62             raise exceptions.IGDError('No IGD found.')
#
# IGDError: No IGD found.
